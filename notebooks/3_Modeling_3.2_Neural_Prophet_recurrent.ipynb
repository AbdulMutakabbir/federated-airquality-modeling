# %%
# ! pip install neuralprophet[live]

# %%
import os
import sys
import torch 
import numpy as np
import pandas as pd
from neuralprophet import NeuralProphet

# %%
path_to_package = os.path.abspath(os.path.join('..'))
if path_to_package not in sys.path:
    sys.path.append(path_to_package)
    
from src.utils.data_model_region import Region

# %%
# Global Constants
# Dataset
DATA_DIR_PATH = "./../data"
DATASET_PATH = f"{DATA_DIR_PATH}/PRSA2017_Data_20130301-20170228"
DATSET_PREPROCESSED_PATH = f"{DATA_DIR_PATH}/preprocessed"

# Model 
IS_HOUR = False
RANDOM_STATE = 1
PAST_WINDOW = 7
if IS_HOUR:
    PAST_WINDOW *= 24
FUTURE_WINDOW = 1
if IS_HOUR:
    FUTURE_WINDOW *= 24
BATCH_SIZE = 2048*16
ROLLING_WINDOW = 30
if IS_HOUR:
    ROLLING_WINDOW *= 24


DATE_COLUMNS = ['year','month','day','hour'] if IS_HOUR else ['year','month','day']
POLUTION_FEATURES = ["PM2.5","PM10","SO2","NO2","CO","O3"]
MODEL_INPUT_FEATURES = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']




def get_preprocessed_dataset_path(region:Region, base_path:str=DATSET_PREPROCESSED_PATH)->str|None:
    """Get path to pre-processed dataset

    Args:
        region (Region): Specifies the region of the dataset
        base_path (str, optional): root dir of the dataset. Defaults to DATASET_PATH.

    Raises:
        ValueError: incorrect region provided

    Returns:
        str|None: returns the datset file path for the region or raises error
    """
    if type(region) == Region:
        return f"{base_path}/{region.value}.csv"
    else:
        raise ValueError("Unkown REGION name!!!")

# %%
regions_df = {}

for region in Region:
    # read datset
    regions_df[region] = pd.read_csv(get_preprocessed_dataset_path(region=region), index_col=None)
    # generate date
    regions_df[region]['date'] = pd.to_datetime(regions_df[region][DATE_COLUMNS])
    regions_df[region].drop(DATE_COLUMNS, axis=1, inplace=True)
    
    regions_df[region].drop('hour', axis=1, inplace=True)
    # group by daily and average
    regions_df[region] = regions_df[region].groupby('date').mean()
    
    # # set datetime index 
    # regions_df[region] = regions_df[region].set_index('date')

    # # cal roll mean
    # regions_df[region] = regions_df[region].rolling(ROLLING_WINDOW).mean().dropna()

    # # create diff
    # regions_df[region] = regions_df[region].diff(1).dropna()

    #standardise
    # regions_df[region] = (regions_df[region]-regions_df[region].mean())/regions_df[region].std()
    # regions_df[region] = (regions_df[region]-regions_df[region].min())/(regions_df[region].max()-regions_df[region].min())
    
    # # add week info
    # regions_df[region]['week'] = regions_df[region].index.to_series().dt.isocalendar().week
    # regions_df[region]['month'] = regions_df[region].index.to_series().dt.month

del region

# %%
regions_df[Region.AOTIZHONGXIN]
# Out:
#                  PM2.5        PM10        SO2         NO2           CO  \
# date
# 2013-03-01    7.125000   10.750000  11.708333   22.583333   429.166667
# 2013-03-02   30.750000   42.083333  36.625000   66.666667   824.916667
# 2013-03-03   76.916667  120.541667  61.291667   81.000000  1620.625000
# 2013-03-04   22.708333   44.583333  23.015778   46.542748   595.019788
# 2013-03-05  148.875000  183.791667  93.875000  132.833333  2357.958333
# ...                ...         ...        ...         ...          ...
# 2017-02-24   21.541667   32.625000  16.583333   58.875000   575.000000
# 2017-02-25   11.208333   19.708333   6.750000   43.375000   420.833333
# 2017-02-26   28.125000   40.708333  10.083333   65.375000   720.833333
# 2017-02-27   71.672674   95.119044  18.875301   92.817051  1364.023741
# 2017-02-28   13.166667   23.291667   9.125000   38.291667   420.833333
#
#                    O3       TEMP         PRES       DEWP  RAIN      WSPM  \
# date
# 2013-03-01  63.875000   1.391667  1026.875000 -18.745833   0.0  3.254167
# 2013-03-02  29.750000   0.616667  1026.850000 -15.937500   0.0  1.479167
# 2013-03-03  19.125000   5.566667  1014.608333 -12.316667   0.0  1.658333
# 2013-03-04  53.750000   9.962500  1017.650000 -11.683333   0.0  2.404167
# 2013-03-05  68.458333   6.291667  1010.900000  -7.525000   0.0  1.129167
# ...               ...        ...          ...        ...   ...       ...
# 2017-02-24  50.791667   5.166667  1021.012500 -11.141667   0.0  1.595833
# 2017-02-25  65.875000   7.245833  1018.812500 -10.754167   0.0  1.825000
# 2017-02-26  48.625000   7.208333  1020.337500  -8.258333   0.0  1.566667
# 2017-02-27  39.963970   8.337500  1017.141667  -7.145833   0.0  1.516667
# 2017-02-28  82.208333  10.958333  1014.887500 -12.783333   0.0  2.058333
#
#                    N         S         E         W
# date
# 2013-03-01  1.000000  0.000000  0.291667  0.416667
# 2013-03-02  0.625000  0.208333  0.583333  0.375000
# 2013-03-03  0.833333  0.083333  0.458333  0.375000
# 2013-03-04  0.500000  0.500000  0.208333  0.416667
# 2013-03-05  0.833333  0.166667  0.708333  0.125000
# ...              ...       ...       ...       ...
# 2017-02-24  0.791667  0.083333  0.333333  0.625000
# 2017-02-25  0.750000  0.166667  0.083333  0.833333
# 2017-02-26  0.541667  0.416667  0.500000  0.416667
# 2017-02-27  0.458333  0.500000  0.500000  0.500000
# 2017-02-28  0.958333  0.000000  0.291667  0.625000
#
# [1461 rows x 15 columns]

# %%
models = {}
metrics = {}
forecasts = {}
dfs = {}

for feature in POLUTION_FEATURES:
    # build model
    models[feature] = NeuralProphet(    
        yearly_seasonality=True,
    weekly_seasonality=True,
    daily_seasonality=True,
    # Add the autogression
    n_lags=2,
    epochs=10
    )
    # build dataset
    dfs[feature] = regions_df[Region.AOTIZHONGXIN][[feature]]
    dfs[feature] = dfs[feature].reset_index()
    dfs[feature].columns = ['ds','y']
    # build metrics
    metrics[feature] = models[feature].fit(dfs[feature], freq="D")
    metrics[feature][['MAE','RMSE','Loss']].plot()
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]

# %%
for feature in POLUTION_FEATURES:
    df_future = models[feature].make_future_dataframe(dfs[feature], n_historic_predictions=True, periods=365)

    # Predict the future
    forecasts[feature] = models[feature].predict(df_future)
    forecasts[feature].set_index('ds')[['y','yhat1']].plot()
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (NP.data.splitting._make_future_dataframe) - Number of forecast steps is defined by n_forecasts. Adjusted to 1.
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (NP.data.splitting._make_future_dataframe) - Number of forecast steps is defined by n_forecasts. Adjusted to 1.
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (NP.data.splitting._make_future_dataframe) - Number of forecast steps is defined by n_forecasts. Adjusted to 1.
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (NP.data.splitting._make_future_dataframe) - Number of forecast steps is defined by n_forecasts. Adjusted to 1.
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (NP.data.splitting._make_future_dataframe) - Number of forecast steps is defined by n_forecasts. Adjusted to 1.
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (NP.data.splitting._make_future_dataframe) - Number of forecast steps is defined by n_forecasts. Adjusted to 1.
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column

# %%
for feature in POLUTION_FEATURES:
    # set index as date time
    forecasts[feature] = forecasts[feature].set_index('ds')
    # rename columns 
    forecasts[feature].columns = [f"{column}_{feature}" for column in forecasts[feature].columns]

combined_fetures_forcast_df = pd.concat(list(forecasts.values()), axis=1)

# %%
combined_fetures_forcast_df
# Out:
#                y_PM2.5  yhat1_PM2.5  trend_PM2.5  season_yearly_PM2.5  \
# ds
# 2013-03-01    7.125000   105.424126    93.466591            14.073109
# 2013-03-02   30.750000   115.678093    93.441238            14.390465
# 2013-03-03   76.916667   110.141624    93.415886            14.642480
# 2013-03-04   22.708333   101.536057    93.390526            14.829145
# 2013-03-05  148.875000   105.811256    93.365173            14.950909
# ...                ...          ...          ...                  ...
# 2017-02-24   21.541667    91.995567    82.570404            11.540744
# 2017-02-25   11.208333   102.609901    82.596039            12.167471
# 2017-02-26   28.125000    97.441269    82.621674            12.736337
# 2017-02-27   71.672674    89.208519    82.647316            13.244813
# 2017-02-28   13.166667    93.859024    82.672951            13.690896
#
#             season_weekly_PM2.5      y_PM10  yhat1_PM10  trend_PM10  \
# ds
# 2013-03-01            -2.115576   10.750000  204.565170  189.912857
# 2013-03-02             7.846391   42.083333  216.393539  189.664871
# 2013-03-03             2.083263  120.541667  212.395966  189.416885
# 2013-03-04            -6.683615   44.583333  203.849365  189.168915
# 2013-03-05            -2.504829  183.791667  208.926682  188.920944
# ...                         ...         ...         ...         ...
# 2017-02-24            -2.115576   32.625000  120.713364  115.233154
# 2017-02-25             7.846391   19.708333  132.956161  115.300896
# 2017-02-26             2.083263   40.708333  129.417419  115.368637
# 2017-02-27            -6.683615   95.119044  121.372597  115.436371
# 2017-02-28            -2.504829   23.291667  126.993057  115.504105
#
#             season_yearly_PM10  season_weekly_PM10  ...         y_CO  \
# ds                                                  ...
# 2013-03-01           16.413437           -1.761123  ...   429.166667
# 2013-03-02           18.170591            8.558071  ...   824.916667
# 2013-03-03           19.881880            3.097197  ...  1620.625000
# 2013-03-04           21.539368           -6.858913  ...   595.019788
# 2013-03-05           23.135530           -3.129786  ...  2357.958333
# ...                        ...                 ...  ...          ...
# 2017-02-24            7.241330           -1.761123  ...   575.000000
# 2017-02-25            9.097196            8.558071  ...   420.833333
# 2017-02-26           10.951580            3.097197  ...   720.833333
# 2017-02-27           12.795144           -6.858913  ...  1364.023741
# 2017-02-28           14.618741           -3.129786  ...   420.833333
#
#                yhat1_CO     trend_CO  season_yearly_CO  season_weekly_CO  \
# ds
# 2013-03-01  1530.952393  1329.888184        202.992142         -1.927971
# 2013-03-02  1613.689209  1329.620239        201.504562         82.564453
# 2013-03-03  1575.878418  1329.352173        198.973511         47.552834
# 2013-03-04  1444.805664  1329.084106        195.360641        -79.639030
# 2013-03-05  1521.395874  1328.816040        190.636002          1.943762
# ...                 ...          ...               ...               ...
# 2017-02-24  1454.650146  1259.881470        196.696594         -1.927971
# 2017-02-25  1541.988037  1259.858887        199.564728         82.564453
# 2017-02-26  1509.091675  1259.836304        201.702545         47.552834
# 2017-02-27  1383.206787  1259.813599        203.032135        -79.639030
# 2017-02-28  1465.217651  1259.791016        203.482956          1.943762
#
#                  y_O3   yhat1_O3   trend_O3  season_yearly_O3  \
# ds
# 2013-03-01  63.875000  28.229887  42.316345        -13.172432
# 2013-03-02  29.750000  28.492952  42.292892        -13.030960
# 2013-03-03  19.125000  32.694466  42.269440        -12.856084
# 2013-03-04  53.750000  31.952105  42.245979        -12.646581
# 2013-03-05  68.458333  28.016321  42.222527        -12.401593
# ...               ...        ...        ...               ...
# 2017-02-24  50.791667  49.544724  63.903236        -13.444489
# 2017-02-25  65.875000  49.694405  63.903641        -13.440262
# 2017-02-26  48.625000  53.771553  63.904045        -13.413601
# 2017-02-27  39.963970  52.895462  63.904457        -13.361703
# 2017-02-28  82.208333  48.818199  63.904861        -13.282050
#
#             season_weekly_O3
# ds
# 2013-03-01         -0.914027
# 2013-03-02         -0.768981
# 2013-03-03          3.281110
# 2013-03-04          2.352704
# 2013-03-05         -1.804616
# ...                      ...
# 2017-02-24         -0.914027
# 2017-02-25         -0.768981
# 2017-02-26          3.281110
# 2017-02-27          2.352704
# 2017-02-28         -1.804616
#
# [1461 rows x 30 columns]

# %%
feature_list = [f"{col}_{feature}" for feature in POLUTION_FEATURES for col in ['yhat1']]
feature  = ["y_PM2.5"]

combined_fetures_forcast_df[feature_list+feature].corr()
# Out:
#              yhat1_PM2.5  yhat1_PM10  yhat1_SO2  yhat1_NO2  yhat1_CO  \
# yhat1_PM2.5     1.000000    0.709815   0.593599   0.845888  0.795265
# yhat1_PM10      0.709815    1.000000   0.676208   0.648647  0.388663
# yhat1_SO2       0.593599    0.676208   1.000000   0.531141  0.577241
# yhat1_NO2       0.845888    0.648647   0.531141   1.000000  0.777920
# yhat1_CO        0.795265    0.388663   0.577241   0.777920  1.000000
# yhat1_O3       -0.746619   -0.551374  -0.612713  -0.885806 -0.777236
# y_PM2.5         0.265160    0.183932   0.159858   0.222397  0.204179
#
#              yhat1_O3   y_PM2.5
# yhat1_PM2.5 -0.746619  0.265160
# yhat1_PM10  -0.551374  0.183932
# yhat1_SO2   -0.612713  0.159858
# yhat1_NO2   -0.885806  0.222397
# yhat1_CO    -0.777236  0.204179
# yhat1_O3     1.000000 -0.198908
# y_PM2.5     -0.198908  1.000000

# %%
import copy
df = copy.deepcopy(forecasts['PM2.5'])

# %%
df['y'] = df['y_PM2.5'] - df['yhat1_PM2.5']
df = df.reset_index()[['ds','y']]
 # build model
model = NeuralProphet()
# build metrics
metric = model.fit(df.reset_index()[['ds','y']], freq="D")
# build forcast
forecast = model.predict(df)
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 173
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column

# %%
metric['RMSE'].plot()
forecast[['y','yhat1']].plot()
# Out:
# <Axes: >

# %%
forecasts['PM2.5']['y_PM2.5'].plot()
(forecasts['PM2.5']['yhat1_PM2.5']+forecast.set_index('ds')['yhat1']).plot()
# Out:
# <Axes: xlabel='ds'>

# %%
for i in range(5):
    df['y'] = forecast['y'] - forecast['yhat1']
    df['ds'] = forecast['ds']
    df = df[['ds','y']]
    # build model
    model = NeuralProphet()
    # build metrics
    metric = model.fit(df.reset_index()[['ds','y']], freq="D")
    # build forcast
    forecast = model.predict(df)
    # plot
    metric['RMSE'].plot()
    forecast.set_index('ds').plot()
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 173
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 173
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (46) is too small than the required number for the learning rate finder (229). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/229 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.932% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 46it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 12
#      10 forecast = model.predict(df)
#      11 # plot
# ---> 12 metric['RMSE'].plot()
#      13 forecast.set_index('ds').plot()
#
# File ~/Projects/federated-airquality-modeling/.venv/lib/python3.10/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Projects/federated-airquality-modeling/.venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/Projects/federated-airquality-modeling/.venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File ~/Projects/federated-airquality-modeling/.venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1382, in LinePlot._make_plot(self)
#    1379 label = self._mark_right_label(label, index=i)
#    1380 kwds["label"] = label
# -> 1382 newlines = plotf(
#    1383     ax,
#    1384     x,
#    1385     y,
#    1386     style=style,
#    1387     column_num=i,
#    1388     stacking_id=stacking_id,
#    1389     is_errorbar=is_errorbar,
#    1390     **kwds,
#    1391 )
#    1392 self._append_legend_handles_labels(newlines[0], label)
#    1394 if self._is_ts_plot():
#    1395
#    1396     # reset of xlim should be used for ts data
#    1397     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~/Projects/federated-airquality-modeling/.venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1433, in LinePlot._ts_plot(self, ax, x, data, style, **kwds)
#    1431 lines = self._plot(ax, data.index, data.values, style=style, **kwds)
#    1432 # set date formatter, locators and rescale limits
# -> 1433 format_dateaxis(ax, ax.freq, data.index)
#    1434 return lines
#
# File ~/Projects/federated-airquality-modeling/.venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/timeseries.py:334, in format_dateaxis(subplot, freq, index)
#     332     subplot.xaxis.set_major_formatter(TimeSeries_TimedeltaFormatter())
#     333 else:
# --> 334     raise TypeError("index type not supported")
#     336 pylab.draw_if_interactive()
#
# TypeError: index type not supported

# %%
df
# Out:
#              ds          y
# 0    2013-03-01 -93.547033
# 1    2013-03-02 -77.316845
# 2    2013-03-03 -23.484134
# 3    2013-03-04 -70.673091
# 4    2013-03-05  49.385576
# ...         ...        ...
# 1456 2017-02-24 -75.485494
# 1457 2017-02-25 -93.336718
# 1458 2017-02-26 -68.893082
# 1459 2017-02-27 -18.477831
# 1460 2017-02-28 -83.253377
#
# [1461 rows x 2 columns]
